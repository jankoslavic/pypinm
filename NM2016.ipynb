# %% [markdown]
# <font size="2"> [github.com/jankoslavic/pypinm](http://github.com/jankoslavic/pypinm)</font>
#
# <center>
# <img width=200 src="./fig/ladisk.png">
# <br>
# <font size="6" color="f00e0e" face="garamond"><b>Numerične metode 2016/17 <br> študijski in izpitni red</b></font>
# <br><br>
# <font size="4">
# [izr.prof. dr. Janko Slavič](http://www.ladisk.si/~slavic)
# </font>
# <br><br>
# <font size="2">September 2016</font>
# </center>

# %% [markdown]
# # Predavanja / vaje

# %% [markdown]
# **Predavanja**:
# * **P** 8:15 V/2
#     * **izr. prof. J. Slavič** (pisarna DS-P3, 01 4771 226, janko.slavic@fs.uni-lj.si)
#
# **Vaje**:
# * **T1** 8:00 I/4: ()
# * **T2** 8:00 II/1: ()
# * **T3** 10:00 I/4: ()
# * **T4** 10:00 II/1: ()
# * **T5** 12:00 I/4: ()
# * **T6** 12:00 II/1: ()
# * **Č1** 8:00 I/4: ()
# * **Č2** 8:00 I/4: ()
# * **Č3** 10:00 I/4: ()
# * **Č4** 10:00 II/1: ()
# * **P1** 8:00 I/4: ()
# * **P2** 8:00 II/1: ()

# %% [markdown]
# **Govorilne ure:**
# * **Ponedeljek 12:30 - 13:30**
#     * tba (pisarna DS-P5, 01 4771 228, tba@fs.uni-lj.si)
#     * tba (pisarna DS-P5, 01 4771 228, tba@fs.uni-lj.si)
#     * tba (pisarna DS-P5, 01 4771 228, tba@fs.uni-lj.si)
#
# **Spremljanje sprotnega študija, obvestila itd**
#
# Sproten študij bomo izvajali s pomočjo: [moj.ladisk.si](http://moj.ladisk.si/). Za prijavo uporabite email, ki ga imate v VIS-u. Video prikaz prijave: [če imate gmail](https://www.youtube.com/watch?v=Xp5lfESTr7w), [poljubni drugi email](https://www.youtube.com/watch?v=vot_ZbARDoE).
#
# **Vprašanja in odgovori:**
#
# Vprašanja na temo predmeta ali tudi širše lahko postavite/odgovorite na portalu: [pinm.ladisk.si](http://pinm.ladisk.si).
#
# **Dodatno delo na računalnikih**
# * Ob četrtkih od 11:30h do 12:30h v I/4.

# %% [markdown]
# **Razpored predavanj**
#
# 1. [3.okt: Uvod v Python](./Predavanje 01 - Uvod v Python.ipynb)
# * [10.okt: Print, delo z datotekami, funkcije, moduli](./Predavanje 02 - Print, delo z datotekami, funkcije, moduli.ipynb)
# * [17.okt: Moduli, numpy, matplotlib](./Predavanje 03 - Moduli, numpy, matplotlib.ipynb)
# * [24.okt: Objektno programiranje, simbolno računanje](./Predavanje 04 - Objektno programiranje, simbolno računanje.ipynb)
# * [7.nov: Sistemi linearnih algebrajskih enačb 1](./Predavanje 05 - Sistemi linearnih algebrajskih enačb 1.ipynb)
# * [14.nov: Sistemi linearnih algebrajskih enačb 2](./Predavanje 06 - Sistemi linearnih algebrajskih enačb 2.ipynb)
# * [21.nov: Interpolacija](./Predavanje 07 - Interpolacija.ipynb)
# * [28.nov: Aproksimacija](./Predavanje 08 - Aproksimacija.ipynb)
# * [5.dec: Iskanje ničel](./Predavanje 09 - Iskanje ničel.ipynb)
# * [12.dec: Numerično odvajanje](./Predavanje 10 - Numerično odvajanje.ipynb)
# * [19.dec: Numerično integriranje](./Predavanje 11 - Numerično integriranje.ipynb)
# * [2.jan: Numerično reševanje diferencialnih enačb - začetni problem](./Predavanje 12 - Numerično reševanje diferencialnih enačb - začetni problem.ipynb)
# * [9.jan: Numerično reševanje diferencialnih enačb - robni problem](./Predavanje 13 - Numerično reševanje diferencialnih enačb - robni problem.ipynb)
# * [9.jan: Testiranje pravilnosti kode, uporabniški vmesnik](./Predavanje 14 - Testiranje pravilnosti kode, uporabniški vmesnik.ipynb)
# * [Uvod v Mathematico*](./Uvod v Mathematico.nb)
#
# \* Fakultativno predavanje, študentje Fakultete za strojništvo UNI-LJ imate možnost pridobiti licenčno verzijo programa Mathematica na tej [povezavi](http://www.fs.uni-lj.si/studijska_dejavnost/it_podpora/programska_oprema_za_studente/2015071415154271/Registracija%20Mathematica/).

# %% [markdown]
# # Sprotni študij

# %% [markdown]
# ## Sestava ocene
#
# * 7,5% sodelovanje pri predavanjih
# * 20% sodelovanje pri vajah* (vsaj 50%)
# * 7,5% tedenske domače naloge (osnove ekosistema Pythona) (vsaj 50%)
# * 15% tedenske domače naloge (numerične metode) (vsaj 50%)
# * 25% individualni projekt (vsaj 50%)
# * 30% preizkus iz teorije (vsaj 50%)
#
# \* Na predavanja in vaje morate priti pripravljeni; uporabili bomo nekatere principe obratnega učenja! Če ne morete priti na vaje, pridete na prve konzultacije na katere lahko.

# %% [markdown]
# ## Individualni projekt
#
# Se navezuje na poljubno vsebino katerega-koli predmeta na FS in ga študent definira sam.
# Projekt mora vsebovati sledeče vsebine:
# * *simbolno reševanje*,
# * *sistemi linearnih enačb*,
# * *interpolacija ali aproksimacija*,
# * *iskanje ničel*,
# * *integriranje ali odvajanje*,
# * *reševanje diferencialnih enačb*.

# %% [markdown]
# Ocena individualnega projekta je sestavljena iz:
# * *numerična pravilnost* (30%),
# * *struktura, urejenost, uporaba modulov, stil kode (docstringi)* (30%),
# * *lasten odnos / kreativni dodatek* (30%),*
# * *pripravljeni testi kode in/ali uporabniški vmesnik* (10%).
#
# Predloga za oddajo je na [github-u](https://github.com/jankoslavic/pypinm/blob/master/projekt/Individualni%20projekt%20-%20predloga.ipynb)

# %% [markdown]
# ## Predlog ocene na podlagi sprotnega študija
#
# * manj kot 40%: ne izpolnjuje pogojev za pristop k izpitu
# * 40% ali več: izpolnjuje pogoje za pristop k izpitu*
# * 50 do 60%: 6/6
# * 60 do 70%: 7/7
# * 70 do 80%: 8/8
# * 80 do 90%: 9/9
# * 90 do 100%: 10/10
#
# Individualni projekt in predlog ocene se zagovarja na ustnem zagovoru.
#
# \* Izpolnjevanje pogojev za pristop k izpitu se lahko ugotavlja tudi brez opravljenega kolokvija iz teorije.

# %% [markdown]
# ## Pomembni datumi
# 1. Oddaja individualnega projekta: 4.jan do 12h.
# * Preizkus iz teorije: 9.jan.
# * Zagovori okvirno: 16.jan-20.jan.
#
#
# Predloge za predmet: [github.com/jankoslavic/pypinm](https://github.com/jankoslavic/pypinm)

# %% [markdown]
# # Izpit

# %% [markdown]
# Če izpolnjujete pogoje za pristop k izpitu, potem lahko obveznosti opravite tudi z izpitom. Izpit se opravlja v dveh delih: 50 min preverjanje uporabe numeričnih metod za računalnikom (tipično dve nalogi, sabo imate lahko poljubne pisne vire, dostopa do interneta ni), nato 60 min za tri teoretična vprašanja. Za pozitivno oceno morata biti oba dela pozitivna.

# %% [markdown]
# # Literatura

# %% [markdown]
# 1. Slavič J.: Programiranje in numerične metode s Pythonom, [github.com/jankoslavic/pypinm](https://github.com/jankoslavic/pypinm), 2015-
# * Petrišič J.: Uvod v Matlab za inženirje, 2011
# * Demšar J. Python za programerje, 2012 (dosegljiva na spletu: http://goo.gl/PK1rUZ, glejte tudi to spletno učilnico: http://goo.gl/n4pVUe)
# * Kiusalaas J: Numerical Methods in Engineering with Python 3, 2013
# * Fangohr H. Python for Computational Science and Engineering, 2014  (dosegljiva na spletu: http://goo.gl/nCOfY0)
# * Bucky R. Python 3.4 Programming Tutorials (videi dosegljivi na: http://goo.gl/ie6nfD)
# * [Projekt TOMO](https://www.projekt-tomo.si) (več vsebin, glejte predvsem predmete na FMF in FRI)
#
# Opomba: za nekatere novejše izraze (npr. terka za tuple) se bomo navezali na: Demšar J., Python za programerje.
#
# Nekatere spletne učilnice na temo Pythona najdete na [pinm.ladisk.si](http://pinm.ladisk.si/9/katera-so-najbolj%C5%A1e-spletne-u%C4%8Dilnice-za-u%C4%8Denje-pythona)

# %% [markdown]
# # Pogoji za poslušanje v naprej?

# %% [markdown]
# Opravljeni predmeti: Matematika 1, Matematika 2, Statika in kinematika, Fizika, Trdnost.
